# %%
import numpy as np
import matplotlib.pyplot as plt
from okean import gshhs
# %matplotlib inline

# %%
x,y=gshhs.get_coastline(xlim=[-10.,37.],ylim=[30,46],res='i')
plt.plot(x,y)
plt.show()

# %%
fname = '../notebooks/data/medsea_coast.npy'
np.ma.vstack((x,y)).dump(fname)
